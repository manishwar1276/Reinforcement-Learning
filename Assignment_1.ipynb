# %% [markdown]
# <a href="https://colab.research.google.com/github/manishwar1276/Reinforcement-Learning/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter number of machines: "))
q = {}
for i in range(n):
    name = input("Enter machine name: ")
    rewards = list(map(int, input("Enter rewards: ").split()))
    q[name] = sum(rewards) / len(rewards)
    print("Machine", name)
    print("Rewards:", rewards)
    print("Q(" + name + ") =", q[name])
best = max(q, key=q.get)
print("Greedy Selected Machine:", best)
# Out:
# Enter number of machines: 3
# Enter machine name: A
# Enter rewards: 3 2 4
# Machine A
# Rewards: [3, 2, 4]
# Q(A) = 3.0
# Enter machine name: B
# Enter rewards: 6 7
# Machine B
# Rewards: [6, 7]
# Q(B) = 6.5
# Enter machine name: C
# Enter rewards: 5 4 6
# Machine C
# Rewards: [5, 4, 6]
# Q(C) = 5.0
# Greedy Selected Machine: B

# %%
n = int(input("Enter number of machines: "))
Q = {}
N = {}
rewards = {}
for i in range(n):
    name = input("Enter machine name: ")
    r = list(map(int, input("Enter rewards: ").split()))
    rewards[name] = r
    Q[name] = 0
    N[name] = 0
print("\nUpdating Q values...\n")
for name in rewards:
    for R in rewards[name]:
        N[name] += 1
        Q[name] = Q[name] + (R - Q[name]) / N[name]
        print("Machine:", name)
        print("Reward:", R)
        print("N =", N[name])
        print("Q =", Q[name])
        print()
print("Final Q Values:")
for name in Q:
    print("Q(" + name + ") =", Q[name])
best = max(Q, key=Q.get)
print("\nGreedy Selected Machine:", best)
# Out:
# Enter number of machines: 3
# Enter machine name: A
# Enter rewards: 3 2 4
# Enter machine name: B
# Enter rewards: 6 7
# Enter machine name: C
# Enter rewards: 5 4 6
#
# Updating Q values...
#
# Machine: A
# Reward: 3
# N = 1
# Q = 3.0
#
# Machine: A
# Reward: 2
# N = 2
# Q = 2.5
#
# Machine: A
# Reward: 4
# N = 3
# Q = 3.0
#
# Machine: B
# Reward: 6
# N = 1
# Q = 6.0
#
# Machine: B
# Reward: 7
# N = 2
# Q = 6.5
#
# Machine: C
# Reward: 5
# N = 1
# Q = 5.0
#
# Machine: C
# Reward: 4
# N = 2
# Q = 4.5
#
# Machine: C
# Reward: 6
# N = 3
# Q = 5.0
#
# Final Q Values:
# Q(A) = 3.0
# Q(B) = 6.5
# Q(C) = 5.0
#
# Greedy Selected Machine: B
